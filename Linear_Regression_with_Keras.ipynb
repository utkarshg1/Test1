# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshg1/Test1/blob/main/Linear_Regression_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression with Keras

# %% [markdown]
# # Runtime > Change Runtime Type > T4 GPU

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # Step 1 - Data ingestion

# %%
url1 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/PowerPlant.csv"
print(url1)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/PowerPlant.csv

# %%
import pandas as pd

df = pd.read_csv(url1)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# # PE - Power output of plant (Target)
# 1. AT - Atmospheric Temperature in degree celsius
# 2. V - Vacuum Pressure
# 3. AP - Atmospheric Pressure
# 4. RH - Relative Humidity

# %% [markdown]
# # Step 2 - Perform basic data quality checks

# %%
df.shape
# Out:
# (9568, 5)

# %%
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df.shape
# Out:
# (9527, 5)

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9527 entries, 0 to 9526
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9527 non-null   float64
#  1   V       9527 non-null   float64
#  2   AP      9527 non-null   float64
#  3   RH      9527 non-null   float64
#  4   PE      9527 non-null   float64
# dtypes: float64(5)
# memory usage: 372.3 KB

# %% [markdown]
# # Step 3 - Seperate X and Y(PE)

# %%
X = df.drop(columns=["PE"])
Y = df["PE"]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
# 0    480.48
# 1    445.75
# 2    438.76
# 3    453.09
# 4    464.43
# Name: PE, dtype: float64

# %% [markdown]
# # Step 4 - Applying train test split

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#          AT      V       AP     RH
# 5695  18.52  58.41  1013.77  99.89
# 7300   8.51  39.66  1015.16  86.61
# 9066  13.07  42.18  1014.98  87.77
# 6424  30.07  69.82  1010.39  57.53
# 6773  13.52  42.34  1017.97  95.34

# %%
ytrain.head()
# Out:
# 5695    446.68
# 7300    483.54
# 9066    461.71
# 6424    437.38
# 6773    463.71
# Name: PE, dtype: float64

# %%
xtest.head()
# Out:
#          AT      V       AP     RH
# 1087  33.26  68.51  1012.49  52.68
# 6308   8.48  38.50  1013.50  66.51
# 8021   8.75  36.30  1015.61  57.53
# 9483  20.78  62.52  1017.58  73.30
# 4459  19.39  68.61  1011.09  96.51

# %%
ytest.head()
# Out:
# 1087    429.38
# 6308    485.29
# 8021    480.40
# 9483    452.30
# 4459    446.47
# Name: PE, dtype: float64

# %%
xtrain.shape
# Out:
# (7621, 4)

# %%
xtest.shape
# Out:
# (1906, 4)

# %% [markdown]
# # Step 6 - Apply Preprocessing on xtrain, xtest

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
).set_output(transform="pandas")

# %%
pipe.fit(xtrain)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
xtrain_pre = pipe.transform(xtrain)
xtest_pre = pipe.transform(xtest)

# %%
xtrain_pre.head()
# Out:
#             AT         V        AP        RH
# 5695 -0.154993  0.323693  0.084610  1.818417
# 7300 -1.504241 -1.151828  0.319064  0.907637
# 9066 -0.889599 -0.953518  0.288703  0.987193
# 6424  1.401831  1.221597 -0.485502 -1.086753
# 6773 -0.828943 -0.940927  0.793033  1.506365

# %%
xtest_pre.head()
# Out:
#             AT         V        AP        RH
# 1087  1.831812  1.118507 -0.131290 -1.419379
# 6308 -1.508285 -1.243114  0.039069 -0.470879
# 8021 -1.471891 -1.416242  0.394967 -1.086753
# 9483  0.149632  0.647127  0.727251 -0.005201
# 4459 -0.037726  1.126376 -0.367431  1.586607

# %% [markdown]
# # Step 7 - Building a neural network

# %%
xtrain_pre.shape
# Out:
# (7621, 4)

# %%
xtrain_pre.shape[1]
# Out:
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense

# %%
model = Sequential(
    layers = [
        Input(shape=(xtrain_pre.shape[1],)),
        Dense(units=8, activation="relu"),
        Dense(units=4, activation="relu"),
        Dense(units=1, activation="linear")
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="mse", optimizer="adam", metrics=["mae"])

# %%
hist = model.fit(xtrain_pre, ytrain, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 207180.5625 - mae: 454.8505 - val_loss: 205782.0781 - val_mae: 453.3090
# Epoch 2/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 206644.9375 - mae: 454.2680 - val_loss: 205542.2344 - val_mae: 453.0460
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 205886.9219 - mae: 453.4301 - val_loss: 201935.4688 - val_mae: 449.0482
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 200399.7344 - mae: 447.3430 - val_loss: 190316.8906 - val_mae: 435.9511
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 186905.9688 - mae: 432.0117 - val_loss: 169443.4062 - val_mae: 411.2602
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 163935.6719 - mae: 404.3965 - val_loss: 141220.7031 - val_mae: 374.7775
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 135101.4688 - mae: 366.1051 - val_loss: 108681.9453 - val_mae: 326.4912
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101495.0469 - mae: 314.3355 - val_loss: 77006.8047 - val_mae: 269.1177
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 70807.5859 - mae: 255.8398 - val_loss: 51545.7109 - val_mae: 209.0906
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 47571.9688 - mae: 199.3364 - val_loss: 34958.5859 - val_mae: 162.5289
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33313.2070 - mae: 158.6352 - val_loss: 25985.4688 - val_mae: 137.7852
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24890.4570 - mae: 134.8785 - val_loss: 21500.6953 - val_mae: 125.7290
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20699.4629 - mae: 123.1939 - val_loss: 18881.6211 - val_mae: 117.9736
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18699.2891 - mae: 117.5217 - val_loss: 16849.4336 - val_mae: 111.3604
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16447.3320 - mae: 109.5026 - val_loss: 14954.5420 - val_mae: 104.7533
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14296.0088 - mae: 102.0602 - val_loss: 13080.3027 - val_mae: 97.8300
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 12462.9141 - mae: 95.6261 - val_loss: 11228.3828 - val_mae: 90.4972
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10363.0264 - mae: 87.1335 - val_loss: 9450.3193 - val_mae: 82.9186
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8678.8916 - mae: 79.4904 - val_loss: 7845.7539 - val_mae: 75.4634
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7175.4224 - mae: 72.2147 - val_loss: 6437.7705 - val_mae: 68.2902
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5834.0806 - mae: 65.3971 - val_loss: 5224.1094 - val_mae: 61.2655
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4699.4863 - mae: 58.0853 - val_loss: 4171.3467 - val_mae: 54.3050
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3690.7512 - mae: 51.3134 - val_loss: 3251.9390 - val_mae: 47.3687
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2868.0662 - mae: 44.5001 - val_loss: 2483.9788 - val_mae: 40.5668
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2132.1499 - mae: 38.0087 - val_loss: 1875.3746 - val_mae: 34.3478
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1622.7819 - mae: 32.1337 - val_loss: 1398.8228 - val_mae: 29.0391
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1200.6591 - mae: 27.3126 - val_loss: 1045.7109 - val_mae: 24.6774
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 963.0394 - mae: 23.8545 - val_loss: 790.6835 - val_mae: 21.0138
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 703.1484 - mae: 20.0895 - val_loss: 598.9380 - val_mae: 18.1981
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 551.5920 - mae: 17.4303 - val_loss: 460.7171 - val_mae: 15.6964
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 414.5294 - mae: 15.0861 - val_loss: 353.9342 - val_mae: 13.6507
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 332.9995 - mae: 13.3986 - val_loss: 276.9803 - val_mae: 11.8246
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 253.8448 - mae: 11.4180 - val_loss: 216.9421 - val_mae: 10.4393
# Epoch 34/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 207.4051 - mae: 10.1996 - val_loss: 170.1626 - val_mae: 9.1130
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 162.0540 - mae: 8.8528 - val_loss: 134.9509 - val_mae: 8.0739
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 127.5727 - mae: 7.7254 - val_loss: 107.5599 - val_mae: 7.1342
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.1856 - mae: 6.9183 - val_loss: 86.3941 - val_mae: 6.4036
# Epoch 38/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 83.5837 - mae: 6.2986 - val_loss: 70.6302 - val_mae: 5.8153
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 73.7964 - mae: 5.8591 - val_loss: 59.0477 - val_mae: 5.3090
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 58.3558 - mae: 5.2343 - val_loss: 50.0424 - val_mae: 4.9415
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 52.0640 - mae: 4.9700 - val_loss: 43.4816 - val_mae: 4.5714
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 43.2320 - mae: 4.6145 - val_loss: 38.2278 - val_mae: 4.3451
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.4080 - mae: 4.4181 - val_loss: 34.4979 - val_mae: 4.1755
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.6760 - mae: 4.1434 - val_loss: 31.5965 - val_mae: 4.0744
# Epoch 45/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.0555 - mae: 4.1466 - val_loss: 29.3310 - val_mae: 3.9639
# Epoch 46/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.8746 - mae: 4.0291 - val_loss: 27.6336 - val_mae: 3.8844
# Epoch 47/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.8103 - mae: 4.0611 - val_loss: 26.1655 - val_mae: 3.8193
# Epoch 48/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.7188 - mae: 3.8827 - val_loss: 25.1787 - val_mae: 3.7798
# Epoch 49/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.7422 - mae: 3.8259 - val_loss: 24.3319 - val_mae: 3.7465
# Epoch 50/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.5045 - mae: 3.8252 - val_loss: 23.6809 - val_mae: 3.7052
# Epoch 51/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.3715 - mae: 3.8174 - val_loss: 23.1226 - val_mae: 3.6805
# Epoch 52/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.5973 - mae: 3.8159 - val_loss: 22.7283 - val_mae: 3.6599
# Epoch 53/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24.7916 - mae: 3.7994 - val_loss: 22.3646 - val_mae: 3.6369
# Epoch 54/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.7012 - mae: 3.6352 - val_loss: 22.0518 - val_mae: 3.6145
# Epoch 55/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.7317 - mae: 3.6583 - val_loss: 21.8319 - val_mae: 3.5966
# Epoch 56/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.7063 - mae: 3.7081 - val_loss: 21.7102 - val_mae: 3.5974
# Epoch 57/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.8134 - mae: 3.7036 - val_loss: 22.1570 - val_mae: 3.6613
# Epoch 58/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.0595 - mae: 3.6786 - val_loss: 21.6172 - val_mae: 3.6095
# Epoch 59/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 21.1262 - mae: 3.6866 - val_loss: 21.7450 - val_mae: 3.6265
# Epoch 60/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.6825 - mae: 3.6427 - val_loss: 21.4402 - val_mae: 3.5958
# Epoch 61/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0686 - mae: 3.6880 - val_loss: 21.4114 - val_mae: 3.6065
# Epoch 62/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.9101 - mae: 3.7471 - val_loss: 21.1424 - val_mae: 3.5655
# Epoch 63/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9134 - mae: 3.5690 - val_loss: 21.1701 - val_mae: 3.5811
# Epoch 64/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.1709 - mae: 3.6316 - val_loss: 21.2856 - val_mae: 3.5840
# Epoch 65/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.7133 - mae: 3.6610 - val_loss: 20.8980 - val_mae: 3.5504
# Epoch 66/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7505 - mae: 3.5781 - val_loss: 21.2581 - val_mae: 3.5785
# Epoch 67/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.1282 - mae: 3.6424 - val_loss: 20.8587 - val_mae: 3.5468
# Epoch 68/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.1090 - mae: 3.6450 - val_loss: 21.0070 - val_mae: 3.5740
# Epoch 69/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8373 - mae: 3.6264 - val_loss: 20.8552 - val_mae: 3.5508
# Epoch 70/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4499 - mae: 3.6179 - val_loss: 21.1437 - val_mae: 3.5873
# Epoch 71/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9165 - mae: 3.6230 - val_loss: 20.9597 - val_mae: 3.5736
# Epoch 72/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9155 - mae: 3.6114 - val_loss: 20.7908 - val_mae: 3.5472
# Epoch 73/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9469 - mae: 3.6434 - val_loss: 20.8746 - val_mae: 3.5467
# Epoch 74/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.5028 - mae: 3.6630 - val_loss: 20.7828 - val_mae: 3.5475
# Epoch 75/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6572 - mae: 3.6020 - val_loss: 20.9179 - val_mae: 3.5581
# Epoch 76/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.0270 - mae: 3.5642 - val_loss: 20.8874 - val_mae: 3.5705
# Epoch 77/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.3781 - mae: 3.6078 - val_loss: 20.8737 - val_mae: 3.5418
# Epoch 78/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 21.3737 - mae: 3.6391 - val_loss: 21.3077 - val_mae: 3.5906
# Epoch 79/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 22.2644 - mae: 3.6683 - val_loss: 21.2435 - val_mae: 3.5784
# Epoch 80/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.2588 - mae: 3.6103 - val_loss: 20.6961 - val_mae: 3.5351
# Epoch 81/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7790 - mae: 3.6249 - val_loss: 20.6337 - val_mae: 3.5353
# Epoch 82/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7183 - mae: 3.6200 - val_loss: 20.8068 - val_mae: 3.5588
# Epoch 83/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7105 - mae: 3.6208 - val_loss: 20.7413 - val_mae: 3.5556
# Epoch 84/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7013 - mae: 3.6227 - val_loss: 20.9460 - val_mae: 3.5667
# Epoch 85/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.3187 - mae: 3.5296 - val_loss: 20.8573 - val_mae: 3.5485
# Epoch 86/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.5974 - mae: 3.5330 - val_loss: 20.7177 - val_mae: 3.5527
# Epoch 87/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.3673 - mae: 3.5512 - val_loss: 20.5780 - val_mae: 3.5273
# Epoch 88/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4431 - mae: 3.5920 - val_loss: 21.7356 - val_mae: 3.6580
# Epoch 89/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6999 - mae: 3.6219 - val_loss: 20.6960 - val_mae: 3.5478
# Epoch 90/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.7553 - mae: 3.5645 - val_loss: 21.0806 - val_mae: 3.6045
# Epoch 91/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.4725 - mae: 3.5325 - val_loss: 20.7848 - val_mae: 3.5479
# Epoch 92/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4260 - mae: 3.5943 - val_loss: 20.6585 - val_mae: 3.5538
# Epoch 93/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.0600 - mae: 3.5591 - val_loss: 20.8447 - val_mae: 3.5701
# Epoch 94/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9212 - mae: 3.5944 - val_loss: 20.8823 - val_mae: 3.5482
# Epoch 95/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8994 - mae: 3.6782 - val_loss: 20.8653 - val_mae: 3.5330
# Epoch 96/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8231 - mae: 3.5828 - val_loss: 22.2520 - val_mae: 3.7185
# Epoch 97/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 21.0995 - mae: 3.6167 - val_loss: 21.0735 - val_mae: 3.5898
# Epoch 98/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 20.3491 - mae: 3.5986 - val_loss: 20.8767 - val_mae: 3.5464
# Epoch 99/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.7830 - mae: 3.6081 - val_loss: 20.7262 - val_mae: 3.5609
# Epoch 100/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.6132 - mae: 3.5610 - val_loss: 20.7890 - val_mae: 3.5720

# %% [markdown]
# # Plot the learning curve

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.plot(hist.history["loss"], label="Training Loss")
plt.plot(hist.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error Loss")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %% [markdown]
# # Step 7 - Evaluate the model

# %%
train_mse, train_mae = model.evaluate(xtrain_pre, ytrain)
print(f"Train MSE : {train_mse:.2f}")
print(f"Train MAE : {train_mae:.2f}")
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.2210 - mae: 3.6054
# Train MSE : 20.41
# Train MAE : 3.59

# %%
test_mse, test_mae = model.evaluate(xtest_pre, ytest)
print(f"Test MSE : {test_mse:.2f}")
print(f"Test MAE : {test_mae:.2f}")
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.1456 - mae: 3.5154
# Test MSE : 20.35
# Test MAE : 3.60

# %%
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)

# %%
def evaluate_model(model, x, y):
  ypred = model.predict(x)
  rmse = root_mean_squared_error(y, ypred)
  mae = mean_absolute_error(y, ypred)
  mape = mean_absolute_percentage_error(y, ypred)
  r2 = r2_score(y, ypred)
  print(f"RMSE : {rmse:.2f}")
  print(f"MAE : {mae:.2f}")
  print(f"MAPE : {mape:.2%}")
  print(f"R2 : {r2:.2%}")

# %%
evaluate_model(model, xtrain_pre, ytrain)
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# RMSE : 4.52
# MAE : 3.59
# MAPE : 0.79%
# R2 : 92.90%

# %%
evaluate_model(model, xtest_pre, ytest)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# RMSE : 4.51
# MAE : 3.60
# MAPE : 0.79%
# R2 : 93.26%

# %% [markdown]
# # Step 8 - Predict results on out of sample data

# %%
url2 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/test_PowerPlant.csv"
print(url2)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/test_PowerPlant.csv

# %%
xnew = pd.read_csv(url2)
xnew
# Out:
#        AT      V       AP     RH
# 0   22.49  58.82  1009.73  85.19
# 1   28.88  54.89  1007.16  46.60
# 2   27.89  73.21  1001.32  85.88
# 3   25.69  62.26  1011.38  74.08
# 4   12.16  40.81  1025.79  70.97
# ..    ...    ...      ...    ...
# 95  26.35  69.48  1008.45  70.47
# 96  11.78  39.96  1011.37  82.95
# 97   5.62  41.38  1020.91  86.21
# 98  24.96  74.99  1008.25  80.52
# 99   9.48  40.80  1023.82  78.98
#
# [100 rows x 4 columns]

# %%
xnew_pre = pipe.transform(xnew)
xnew_pre.head()
# Out:
#          AT         V        AP        RH
# 0  0.380123  0.355958 -0.596825  0.810249
# 1  1.241431  0.046688 -1.030313 -1.836363
# 2  1.107989  1.488371 -2.015358  0.857571
# 3  0.811451  0.626666 -0.318516  0.048294
# 4 -1.012258 -1.061330  2.112049 -0.164999

# %%
preds = model.predict(xnew_pre)
preds[0:5]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# array([[445.40744],
#        [439.66177],
#        [430.43536],
#        [440.3558 ],
#        [473.92975]], dtype=float32)

# %%
xnew["PE_pred"] = preds.round(2)
xnew.head()
# Out:
#       AT      V       AP     RH     PE_pred
# 0  22.49  58.82  1009.73  85.19  445.410004
# 1  28.88  54.89  1007.16  46.60  439.660004
# 2  27.89  73.21  1001.32  85.88  430.440002
# 3  25.69  62.26  1011.38  74.08  440.359985
# 4  12.16  40.81  1025.79  70.97  473.929993

# %%
xnew.to_csv("plant_res.csv", index=False)

# %% [markdown]
# # Save the mdoel object

# %%
model.save("plant_model.keras")

# %% [markdown]
# # Load Model Object Again

# %%
from tensorflow.keras.models import load_model

m = load_model("plant_model.keras")
m.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)
