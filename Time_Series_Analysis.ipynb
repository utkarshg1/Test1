# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshg1/Test1/blob/main/Time_Series_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Time series decomposition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
url = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/AirPassengers.csv"
print(url)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/AirPassengers.csv

# %%
import pandas as pd
df = pd.read_csv(url, parse_dates=["Month"])
df.head()
# Out:
#        Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
df.dtypes
# Out:
# Month         datetime64[ns]
# Passengers             int64
# dtype: object

# %% [markdown]
# ### Visulaize the actual data

# %%
df2 = df.copy()
df2 = df2.set_index("Month")
df2.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
plt.plot(df2["Passengers"])
plt.xlabel("Month")
plt.ylabel("Air Passengers")
plt.title("Monthly Air Passengers")
plt.grid()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Multiplicative decomposition is more suitable to this

# %% [markdown]
# ## Apply decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
q = seasonal_decompose(df2["Passengers"], model="mul")

# %%
q.observed
# Out:
# Month
# 1949-01-01    112.0
# 1949-02-01    118.0
# 1949-03-01    132.0
# 1949-04-01    129.0
# 1949-05-01    121.0
#               ...
# 1960-08-01    606.0
# 1960-09-01    508.0
# 1960-10-01    461.0
# 1960-11-01    390.0
# 1960-12-01    432.0
# Name: Passengers, Length: 144, dtype: float64

# %%
q.trend.head(10)
# Out:
# Month
# 1949-01-01           NaN
# 1949-02-01           NaN
# 1949-03-01           NaN
# 1949-04-01           NaN
# 1949-05-01           NaN
# 1949-06-01           NaN
# 1949-07-01    126.791667
# 1949-08-01    127.250000
# 1949-09-01    127.958333
# 1949-10-01    128.583333
# Name: trend, dtype: float64

# %%
q.seasonal
# Out:
# Month
# 1949-01-01    0.910230
# 1949-02-01    0.883625
# 1949-03-01    1.007366
# 1949-04-01    0.975906
# 1949-05-01    0.981378
#                 ...
# 1960-08-01    1.219911
# 1960-09-01    1.060492
# 1960-10-01    0.921757
# 1960-11-01    0.801178
# 1960-12-01    0.898824
# Name: seasonal, Length: 144, dtype: float64

# %%
q.resid.head(10)
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01    0.951664
# 1949-08-01    0.953401
# 1949-09-01    1.002220
# 1949-10-01    1.004028
# Name: resid, dtype: float64

# %%
q.plot()

# %%
plt.figure(figsize=(12, 5))
q.observed.plot()
q.trend.plot()
plt.xlabel("Month")
plt.ylabel("Air Passengers")
plt.title("Air Passengers Trend")
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 5))
q.seasonal.plot()
plt.xlabel("Month")
plt.ylabel("Air Passengers")
plt.title("Air Passengers Seasonality")
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 5))
q.resid.plot()
plt.xlabel("Month")
plt.ylabel("Air Passengers")
plt.title("Air Passengers Residuals")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Time series forecasting
# - statsforecast

# %%
# %pip install statsforecast
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 8.5 MB/s eta 0:00:00
# ...

# %%
df
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %%
df = df.rename(columns={"Month": "ds", "Passengers": "y"})
df.head()
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
df["unique_id"] = "air_passengers"

# %%
df.head()
# Out:
#           ds    y       unique_id
# 0 1949-01-01  112  air_passengers
# 1 1949-02-01  118  air_passengers
# 2 1949-03-01  132  air_passengers
# 3 1949-04-01  129  air_passengers
# 4 1949-05-01  121  air_passengers

# %%
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA

# %%
sf = StatsForecast(
    models = [AutoARIMA(season_length=12)],
    freq="MS"
)

# %%
sf.fit(df)
# Out:
# StatsForecast(models=[AutoARIMA])

# %% [markdown]
# ### Estimate values for next 3 years

# %%
n_years = 3
n_months = n_years * 12
ypred = sf.predict(h=n_months, level=[95])
ypred = ypred.round(0)
ypred
# Out:
#          unique_id         ds  AutoARIMA  AutoARIMA-lo-95  AutoARIMA-hi-95
# 0   air_passengers 1961-01-01      444.0            421.0            467.0
# 1   air_passengers 1961-02-01      418.0            390.0            446.0
# 2   air_passengers 1961-03-01      446.0            413.0            480.0
# 3   air_passengers 1961-04-01      488.0            451.0            526.0
# 4   air_passengers 1961-05-01      499.0            458.0            541.0
# 5   air_passengers 1961-06-01      562.0            517.0            607.0
# 6   air_passengers 1961-07-01      649.0            601.0            698.0
# 7   air_passengers 1961-08-01      633.0            582.0            685.0
# 8   air_passengers 1961-09-01      535.0            481.0            590.0
# 9   air_passengers 1961-10-01      488.0            431.0            545.0
# 10  air_passengers 1961-11-01      417.0            357.0            477.0
# ...

# %%
df
# Out:
#             ds    y       unique_id
# 0   1949-01-01  112  air_passengers
# 1   1949-02-01  118  air_passengers
# 2   1949-03-01  132  air_passengers
# 3   1949-04-01  129  air_passengers
# 4   1949-05-01  121  air_passengers
# ..         ...  ...             ...
# 139 1960-08-01  606  air_passengers
# 140 1960-09-01  508  air_passengers
# 141 1960-10-01  461  air_passengers
# 142 1960-11-01  390  air_passengers
# 143 1960-12-01  432  air_passengers
#
# [144 rows x 3 columns]

# %%
ypred.to_csv("Results.csv", index=False)

# %% [markdown]
# ### Visualizing above results

# %%
historical_data = df[["ds", "y"]].set_index("ds")
historical_data
# Out:
#               y
# ds
# 1949-01-01  112
# 1949-02-01  118
# 1949-03-01  132
# 1949-04-01  129
# 1949-05-01  121
# ...         ...
# 1960-08-01  606
# 1960-09-01  508
# 1960-10-01  461
# 1960-11-01  390
# 1960-12-01  432
#
# [144 rows x 1 columns]

# %%
forecast_data = ypred[["ds", "AutoARIMA"]].set_index("ds")
forecast_data
# Out:
#             AutoARIMA
# ds
# 1961-01-01      444.0
# 1961-02-01      418.0
# 1961-03-01      446.0
# 1961-04-01      488.0
# 1961-05-01      499.0
# 1961-06-01      562.0
# 1961-07-01      649.0
# 1961-08-01      633.0
# 1961-09-01      535.0
# 1961-10-01      488.0
# 1961-11-01      417.0
# 1961-12-01      459.0
# 1962-01-01      472.0
# 1962-02-01      445.0
# 1962-03-01      473.0
# 1962-04-01      515.0
# 1962-05-01      526.0
# 1962-06-01      589.0
# 1962-07-01      676.0
# 1962-08-01      660.0
# 1962-09-01      562.0
# 1962-10-01      515.0
# 1962-11-01      444.0
# 1962-12-01      486.0
# 1963-01-01      499.0
# 1963-02-01      473.0
# 1963-03-01      501.0
# 1963-04-01      543.0
# 1963-05-01      554.0
# 1963-06-01      617.0
# 1963-07-01      704.0
# 1963-08-01      688.0
# 1963-09-01      590.0
# 1963-10-01      543.0
# 1963-11-01      472.0
# 1963-12-01      514.0

# %%
ypred.columns
# Out:
# Index(['unique_id', 'ds', 'AutoARIMA', 'AutoARIMA-lo-95', 'AutoARIMA-hi-95'], dtype='object')

# %%
plt.figure(figsize=(12, 5))
plt.plot(historical_data["y"], label="Historical Data")
plt.plot(forecast_data["AutoARIMA"], label="Forecast Data", color="red")
plt.fill_between(
    forecast_data.index,
    ypred["AutoARIMA-lo-95"],
    ypred["AutoARIMA-hi-95"],
    color = "red",
    alpha=0.2,
    label = "95% confidence interval"
)
plt.xlabel("Months")
plt.ylabel("Air Passengers")
plt.title("Air Passengers Forecast")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Saving model object

# %%
# %pip install joblib

# %%
import joblib
joblib.dump(sf, "arima.joblib")
# Out:
# ['arima.joblib']

# %% [markdown]
# ### Loading the model

# %%
m = joblib.load("arima.joblib")
m
# Out:
# StatsForecast(models=[AutoARIMA])
